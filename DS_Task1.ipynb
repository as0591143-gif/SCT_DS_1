# %%
>>> import matplotlib.pyplot as plt
...
... # Data
... age_groups = ['0-20', '21-40', '41-60', '60+']
... population_percent = [34.11, 33.64, 23.35, 8.90]
...
... # Bar Chart
... plt.bar(age_groups, population_percent, color=['yellow','blue','purple','pink'])
... plt.title("India's Population Distribution by Age (2022)")
... plt.xlabel("Age Groups")
... plt.ylabel("Percentage of Population")
... plt.show()
...
